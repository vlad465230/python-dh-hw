# %% [markdown]
# # Задание №1
#
# Скачайте текст "Литературных анекдотов". Напишите функцию, которая будет читать файл, лемматизировать текст с помощью pymystem3 и записывать результат в новый файл. У функции должно бы два аргумента: путь к исходному файлу и путь к файлу с лемматизированным текстом. Вызов функции тоже должен быть прописан в решении.

# %%
from pymystem3 import Mystem

def function(file1, file2): #создаем функцию с двумя аргументами
    a = open(file1, encoding = 'utf-8') #открываем файл 
    text = a.read() #читаем файл и записываем текст из файла в переменную
    lem = Mystem()
    lemmas = lem.lemmatize(text) #лемматизируем текст с помощью pymystem3
    clean_lemmas = [w for w in lemmas if w.isalpha()] #очищаем текст от пунктуации и возможных чисел
    lemmas1=' '.join(clean_lemmas) #объединяем лемматизированный текст в строку через пробел
    a.close()
    with open(file2, 'w', encoding='utf-8') as f: #создаем функцию, которая записывает лемм. текст в новый файл
        for d in lemmas1:
            f.write(d)
    f.close()

function('/Users/vladislavturin/Desktop/Python/python-dh-hw/Литературные анекдоты', 'lemmas.txt')
# вызываю функцию и присваиваю значения аргументам

#открываем и читаем новый файл и записываем его в переменную, чтобы использовать в дальнейшем
b = open('lemmas.txt', 'r', encoding = 'utf-8') #открываем новый файл с лем. текстом, чтобы проверить и записать в переменную
lemy = b.read()
b.close()

# %% [markdown]
# # Задание 2
#
# Очистите лемматизированный текст от стоп-слов и посчитайте ipm для оставшихся. Выведите 20 самых частотных по этому параметру слов.

# %%
with open('/Users/vladislavturin/Desktop/stopwords', 'r', encoding='utf-8') as g: 
     stopwords = g.read() #читаем файл со стоп-словами и записываем текст из файла в переменную
g.close()

lemy1 = lemy.split() #разделяем лем. текст на слова
s_w = stopwords.split() #разделяем текст стоп-слов на слова

no_stop_words = [w for w in lemy1 if w not in s_w] #избавляемся с от стоп-слов
no_stop_words1 = ' '.join(no_stop_words) #объединяем текст в строку

from collections import Counter 

counts = Counter(no_stop_words1.split()) #вычисляем наиболее частотные слова в тексте

print(counts.most_common(20)) #выводим 20 наиболее частотных слов
# Out:
# [('пушкин', 56), ('толстой', 33), ('гоголь', 31), ('однажды', 29), ('лев', 25), ('любить', 20), ('достоевский', 19), ('ребенок', 15), ('тургенев', 15), ('царствие', 13), ('окно', 12), ('тверской', 12), ('бульвар', 12), ('приходить', 12), ('лермонтов', 12), ('идти', 11), ('федор', 11), ('михайлович', 11), ('герцен', 10), ('небесный', 10)]

# %% [markdown]
# # Задание №3
#
# 1) Сделайте полный морфологический разбор исходного текста.

# %%
from pymystem3 import Mystem 
import json

a = open('Литературные анекдоты', 'r', encoding = 'utf-8') #открываем файл 
text = a.read() #читаем файл и записываем текст из файла в переменную
lem = Mystem()
lemmas = lem.lemmatize(text) #лемматизируем текст с помощью pymystem3

morfolog = lem.analyze(text) #делаем полный морфологический разбор с помощью функция analyze

# %% [markdown]
# 2) Напишите регулярное выражение, которое будет извлекать из тега только часть речи.

# %%
#созадю строку, в которую с помощью цикла достаю из словаря только грамматический разбор слов
#это понадобится для для дальнейшего извлечения из тега только частей речи
words = {}
for word in morfolog:
    try:
        form = word['text']
        gr = word['analysis'][0]['gr']
        words[form] = gr
    except (IndexError,KeyError):
        pass

# %%
#импортируем библиотеку регулярных выражений
import re

#пишем регулярное выражение и цикл, который будет доставать из тега только часть речи, не совсем тут разобрался, но мы так на семинаре делали!
chast = re.compile('[A-Z]+')
rechi = {}

for k, v in words.items():
    print(chast.match(v))
    rechi[k] = chast.match(v).group(0)
# Out:
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='ANUM'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='ANUM'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='ANUM'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='ANUM'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='CONJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 3), match='ADV'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 3), match='NUM'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 2), match='PR'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='INTJ'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 4), match='APRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='A'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='SPRO'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 6), match='ADVPRO'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 1), match='S'>
# <re.Match object; span=(0, 4), match='PART'>
# <re.Match object; span=(0, 1), match='V'>
# <re.Match object; span=(0, 1), match='V'>

# %% [markdown]
# 3) Пройдитесь циклом по списку с разборами, который выдал pymystem3, извлекая из каждого разбора форму слова и его часть речи и записывая их в новый словарь (форма -- ключ, часть речи -- значение).

# %%
#если я распечатаю переменную rechi у меня выйдет нужный для этого задания словарь, но так как я не совсем понял как так произошло, так как использовал записи с семинара, попробую сделать это задание другим способом
#создаем словарь
slovar = dict()

#делаем цикл, который оставляет в словаре форму слова и его часть речи
for word in morfolog:
    try:
        form = word['text']
        #с помощью регулярки оставляем только в значении часть речи, так как она пишется латинскими буквами
        gr = word['text']=re.match('[A-Z]+',word['analysis'][0]['gr']).group()
        slovar[form] = gr
    except (IndexError,KeyError): 
        pass

print(slovar)
# Out:
# {'У': 'PR', 'Вяземского': 'S', 'была': 'V', 'квартира': 'S', 'окнами': 'S', 'на': 'PR', 'Тверской': 'A', 'бульвар': 'S', 'Пушкин': 'S', 'очень': 'ADV', 'любил': 'V', 'ходить': 'V', 'к': 'PR', 'нему': 'SPRO', 'в': 'PR', 'гости': 'S', 'Придет': 'V', 'и': 'CONJ', 'сразу': 'ADV', 'прыг': 'ADV', 'подоконник': 'S', 'свесится': 'V', 'из': 'PR', 'окна': 'S', 'смотрит': 'V', 'Чай': 'S', 'ему': 'SPRO', 'тоже': 'PART', 'туда': 'ADVPRO', 'окно': 'S', 'подавали': 'V', 'Иной': 'APRO', 'раз': 'S', 'там': 'ADVPRO', 'заночует': 'V', 'Ему': 'SPRO', 'даже': 'PART', 'матрац': 'S', 'купили': 'V', 'специальный': 'A', 'только': 'PART', 'он': 'SPRO', 'его': 'SPRO', 'не': 'PART', 'признавал': 'V', 'К': 'PR', 'чему': 'SPRO', 'говорит': 'V', 'такие': 'APRO', 'роскоши': 'S', 'И': 'CONJ', 'спихнет': 'V', 'с': 'PR', 'подоконника': 'S', 'А': 'CONJ', 'потом': 'ADVPRO', 'всю': 'APRO', 'ночь': 'S', 'вертится': 'V', 'спать': 'V', 'дает': 'V', 'Гоголь': 'S', 'переоделся': 'V', 'Пушкиным': 'S', 'пришел': 'V', 'Пушкину': 'S', 'позвонил': 'V', 'открыл': 'V', 'кричит': 'V', 'Смотри': 'V', 'Арина': 'S', 'Родионовна': 'S', 'я': 'SPRO', 'Лермонтов': 'S', 'хотел': 'V', 'у': 'PR', 'Пушкина': 'S', 'жену': 'S', 'увести': 'V', 'На': 'PR', 'Кавказ': 'S', 'Все': 'APRO', 'смотрел': 'V', 'нее': 'SPRO', 'из-за': 'PR', 'колонн': 'S', 'Вдруг': 'ADV', 'устыдился': 'V', 'своих': 'APRO', 'желаний': 'S', 'думает': 'V', 'зеркало': 'S', 'русской': 'A', 'революции': 'S', 'а': 'CONJ', 'свинья': 'S', 'Пошел': 'V', 'встал': 'V', 'перед': 'PR', 'ним': 'SPRO', 'колени': 'S', 'где': 'ADVPRO', 'твой': 'APRO', 'кинжал': 'S', 'Вот': 'PART', 'грудь': 'S', 'моя': 'APRO', 'смеялся': 'V', 'Однажды': 'ADV', 'стрелялся': 'V', 'Гоголем': 'S', 'Стреляй': 'V', 'первым': 'ANUM', 'ты': 'SPRO', 'Как': 'ADVPRO', 'Нет': 'PART', 'Ах': 'INTJ', 'Так': 'ADVPRO', 'стали': 'V', 'стреляться': 'V', 'Лев': 'S', 'Толстой': 'S', 'детей': 'S', 'шел': 'V', 'по': 'PR', 'Тверскому': 'A', 'бульвару': 'S', 'увидел': 'V', 'впереди': 'PR', 'Конечно': 'ADV', 'это': 'SPRO', 'уже': 'ADV', 'ребенок': 'S', 'подросток': 'S', 'подумал': 'V', 'все': 'SPRO', 'равно': 'A', 'дай': 'V', 'догоню': 'V', 'поглажу': 'V', 'головке': 'S', 'побежал': 'V', 'догонять': 'V', 'же': 'PART', 'зная': 'V', 'толстовских': 'A', 'намерений': 'S', 'бросился': 'V', 'наутек': 'ADV', 'Пробегая': 'V', 'мимо': 'ADV', 'городового': 'S', 'сей': 'APRO', 'страж': 'S', 'порядка': 'S', 'был': 'V', 'возмущен': 'V', 'неприличной': 'A', 'быстротою': 'S', 'бега': 'S', 'людном': 'A', 'месте': 'S', 'бегом': 'ADV', 'устремился': 'V', 'вслед': 'ADV', 'целью': 'S', 'остановить': 'V', 'Западная': 'A', 'пресса': 'S', 'писала': 'V', 'что': 'CONJ', 'России': 'S', 'литераторы': 'S', 'подвергаются': 'V', 'преследованиям': 'S', 'со': 'PR', 'стороны': 'S', 'властей': 'S', 'купил': 'V', 'яблок': 'S', 'стал': 'V', 'угощать': 'V', 'присутствующих': 'V', 'дам': 'V', 'брали': 'V', 'говорили': 'V', 'мерси': 'S', 'Когда': 'ADVPRO', 'подошла': 'V', 'Наталья': 'S', 'Николаевна': 'S', 'сестрой': 'S', 'Александриной': 'S', 'от': 'PR', 'волненья': 'S', 'так': 'ADVPRO', 'задрожал': 'V', 'яблоко': 'S', 'упало': 'V', 'ее': 'SPRO', 'ногам': 'S', 'Натальи': 'S', 'Николаевны': 'S', 'Александрины': 'S', 'Одна': 'APRO', 'собак': 'S', 'схватила': 'V', 'бросилась': 'V', 'бежать': 'V', 'Александрина': 'S', 'конечно': 'ADV', 'побежала': 'V', 'за': 'PR', 'ней': 'SPRO', 'Они': 'SPRO', 'были': 'V', 'одни': 'APRO', 'впервые': 'ADV', 'жизни': 'S', 'Александ': 'S', 'рина': 'S', 'собачкой': 'S', 'Кстати': 'ADV', 'она': 'SPRO', 'догнала': 'V', 'решил': 'V', 'испугать': 'V', 'Тургенева': 'S', 'спрятался': 'V', 'Тверском': 'A', 'бульваре': 'S', 'под': 'PR', 'лавкой': 'S', 'этот': 'APRO', 'день': 'S', 'другой': 'APRO', 'Тут': 'ADVPRO', 'Тургенев': 'S', 'идет': 'V', 'они': 'SPRO', 'оба': 'NUM', 'выскочат': 'V', 'играл': 'V', 'ними': 'SPRO', 'весь': 'APRO', 'проголодался': 'V', 'Сонечка': 'S', 'ангелочек': 'S', 'сде': 'S', 'лай': 'S', 'мне': 'SPRO', 'тюрьку': 'S', 'Она': 'SPRO', 'возражает': 'V', 'Левушка': 'S', 'видишь':  ...

# %% [markdown]
# 4) Посчитайте абсолютную частоту для всех частей речи, а затем относительнную частоту (абсолютная частота / длина текста в словах).

# %%
#делаем из словаря строку
str1 = str(words_pos)

#считаем абсолютную чистоту, т.е. кол-во каждой части речи в тексте
counts = Counter(str1.split())

#выводим наиболее частотные 13 значений, так как их в Mystem 14, но у нас нет COM
print(counts.most_common(13))
# Out:
# [("'S',", 499), ("'V',", 427), ("'A',", 98), ("'ADV',", 88), ("'SPRO',", 55), ("'APRO',", 48), ("'PR',", 37), ("'PART',", 29), ("'ADVPRO',", 24), ("'CONJ',", 20), ("'NUM',", 9), ("'INTJ',", 8), ("'ANUM',", 4)]

# %%
len(lemy1) #считаем кол-во слов в тексте
# Out:
# 2852
