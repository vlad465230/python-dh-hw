# %%
a = open('/Users/vladislavturin/Desktop/Капитанская дочка', 'r', encoding = 'utf-8') 
text = a.read()
a.close()

# %%
words = [word.strip("!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~„“«»†*—/\-") for word in text.split()] 
t2 = ' '.join(words)

# %%
from pymystem3 import Mystem

l = Mystem()
lemmas = m.lemmatize(t2)

print(''.join(lemmas))
# Out:
#  быть бы гвардия он завтра ж капитан  то не надобно пусть в армия послужить  изрядно сказать пускай он потужить                             да кто он отец княжнин отец мой андрей петрович гринев в молодость свой служить при графа миних и выходить в отставка премьер-майор в 17 год с тот пора жить он в свой симбирский деревня где и жениться на девица авдотья васильевна ю дочь бедный тамошний дворянин мы быть девять человек ребенок весь мой брат и сестра умирать во младенчество матушка быть еще я брюхатый как уже я быть записывать в семеновский полк сержант по милость майор гвардия князь б близкий наш родственник если бы паче всякий чаяние матушка рожать дочь то батюшка объявлять бы куда следовать о смерть неявиться сержант и дело то бы и кончаться я считаться в отпуск до окончание наука в тот время воспитываться мы не по-нонешний с пятилетний возраст отдавать я быть на рука стремянный савельич за трезвый поведение пожаловать я в дядька под его надзор на двенадцатый год выучиваться я ру
# ...

# %%
from collections import Counter #считаем частотность во всем тексте
с = Counter(lemmas)
print(c)
# Out:
# Counter({' ': 31788, 'я': 1478, 'и': 1307, '  ': 1079, 'в': 766, 'он': 637, 'не': 634, 'что': 507, 'быть': 506, 'на': 477, 'с': 456, 'ты': 349, 'мой': 337, 'она': 286, 'мы': 255, 'сказать': 253, 'к': 240, 'а': 234, 'за': 203, 'свой': 194, 'как': 186, 'то': 183, 'они': 148, 'пугачев': 148, 'по': 144, 'но': 144, 'который': 140, 'у': 138, 'его': 137, 'марья': 137, 'вы': 136, 'ивановна': 136, 'да': 134, 'из': 132, 'от': 128, 'о': 118, 'отвечать': 118, 'савельич': 111, 'себя': 108, 'весь': 107, 'мочь': 103, 'это': 103, 'так': 98, 'же': 96, 'крепость': 96, 'иван': 95, 'наш': 94, 'становиться': 94, 'все': 93, 'ли': 90, 'бог': 89, 'батюшка': 88, 'один': 88, 'ни': 88, 'этот': 83, 'человек': 82, '-': 80, 'швабрин': 80, 'еще': 74, 'рука': 74, 'комендант': 73, 'бы': 72, 'петр': 67, 'ваш': 65, 'тот': 63, 'со': 62, 'знать': 61, 'увидеть': 60, 'минута': 60, 'спрашивать': 59, 'дело': 58, 'несколько': 57, 'отец': 56, 'кузмич': 56, 'слово': 55, 'твой': 54, 'андреич': 53, 'под': 52, 'говорить': 52, 'ма
# ...
